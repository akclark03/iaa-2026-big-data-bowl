# %%
import sys
import os
import pandas as pd

sys.path.append(os.path.abspath(os.path.join(os.getcwd(), "..")))
import nfl_competition_analytics.data as nfl_data

# %%
dfs = nfl_data.load_data(data_dir="../data/train")

# %%
play_df = nfl_data.get_play_data(
    dfs,
    week="w01",
    game_id=2023090700,
    play_id=1741,
    output=True,
)
play_df["nfl_id"].unique()
play_df[play_df["nfl_id"] == 44888]
# Out:
#         game_id  play_id  player_to_predict  nfl_id  frame_id play_direction  \
# 0    2023090700     1741               True   44888         1          right
# 1    2023090700     1741               True   44888         2          right
# 2    2023090700     1741               True   44888         3          right
# 3    2023090700     1741               True   44888         4          right
# 4    2023090700     1741               True   44888         5          right
# 5    2023090700     1741               True   44888         6          right
# 6    2023090700     1741               True   44888         7          right
# 7    2023090700     1741               True   44888         8          right
# 8    2023090700     1741               True   44888         9          right
# 9    2023090700     1741               True   44888        10          right
# 10   2023090700     1741               True   44888        11          right
# ...
